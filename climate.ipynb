# %%
#import matplotlib.pyplot as plt # matplotlib not working. "no module named 'matplotlib' error"
import pandas as pd
import numpy as np

# %%
pip install intake-esgf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing esgf catalogue
from intake_esgf import ESGFCatalog
cat = ESGFCatalog()

# %%
cat.search(variable_id="tas",experiment_id="historical")
# Out:
#    Searching indices:   0%|          |0/1 [       ?index/s]
# Summary information for 1908 results:
# mip_era                                                     [CMIP6]
# activity_drs                                                 [CMIP]
# institution_id    [AS-RCEC, AWI, BCC, CAMS, CAS, CCCR-IITM, CCCm...
# source_id         [TaiESM1, AWI-CM-1-1-MR, AWI-ESM-1-1-LR, BCC-C...
# experiment_id                                          [historical]
# member_id         [r1i1p1f1, r2i1p1f1, r3i1p1f1, r4i1p1f1, r5i1p...
# table_id          [3hr, Amon, day, 6hrPlev, 6hrPlevPt, AERhr, CF...
# variable_id                                                   [tas]
# grid_label                             [gn, gr, gr1, gra, grg, gr2]
# dtype: object

# %%
cat.search(
    variable_id="tas",
    experiment_id="historical",
    source_id="CanESM5",
    member_id="r1i1p1f1",
    table_id="day"
)
# Out:
#    Searching indices:   0%|          |0/1 [       ?index/s]
# Summary information for 1 results:
# mip_era                [CMIP6]
# activity_drs            [CMIP]
# institution_id         [CCCma]
# source_id            [CanESM5]
# experiment_id     [historical]
# member_id           [r1i1p1f1]
# table_id                 [day]
# variable_id              [tas]
# grid_label                [gn]
# dtype: object

# %%
dsd = cat.to_dataset_dict()
# Out:
# ...
# Adding cell measures:   0%|          |0/1 [     ?dataset/s]

# %%
cat.variable_info('scenario pathway')
# Out:
#                            cf_standard_name              variable_long_name  \
# variable_id
# hus                       specific_humidity               Specific Humidity
# huss                      specific_humidity  Near-Surface Specific Humidity
# pr                       precipitation_flux                   Precipitation
# prsn                          snowfall_flux                   Snowfall Flux
# psl          air_pressure_at_mean_sea_level              Sea Level Pressure
# ta                          air_temperature                 Air Temperature
# tas                         air_temperature    Near-Surface Air Temperature
# ua                            eastward_wind                   Eastward Wind
# va                           northward_wind                  Northward Wind
# zg                      geopotential_height             Geopotential Height
#
#             variable_units
# variable_id
# hus                      1
# huss                     1
# ...

# %%
cat.search(
    variable_id="tasmin",
    experiment_id="historical",
    source_id="CanESM5",
    member_id="r1i1p1f1",
    table_id="day"
) 
# if i comment out CanESM5, it says there are 44 results & 320 GB of data to download
# Out:
#    Searching indices:   0%|          |0/1 [       ?index/s]
# Summary information for 1 results:
# mip_era                [CMIP6]
# activity_drs            [CMIP]
# institution_id         [CCCma]
# source_id            [CanESM5]
# experiment_id     [historical]
# member_id           [r1i1p1f1]
# table_id                 [day]
# variable_id           [tasmin]
# grid_label                [gn]
# dtype: object

# %%
dsd = cat.to_dataset_dict()
# Out:
# Get file information:   0%|          |0/1 [       ?index/s]
# ...
# tasmin_day_CanESM5_historical_r1i1p1f...:   0%|          |0.00/1.61G [?B/s]
# Adding cell measures:   0%|          |0/1 [     ?dataset/s]

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
