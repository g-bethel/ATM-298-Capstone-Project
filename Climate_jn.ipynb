# %%
import matplotlib.pyplot as plt

# %%
pip install intake-esgf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: intake-esgf in ./.local/lib/python3.12/site-packages (2026.1.26)
# Requirement already satisfied: dask>=2024.12.0 in ./.local/lib/python3.12/site-packages (from intake-esgf) (2026.1.2)
# Requirement already satisfied: globus-sdk<4.0.0 in ./.local/lib/python3.12/site-packages (from intake-esgf) (3.65.0)
# Requirement already satisfied: netcdf4>=1.7.2 in ./.local/lib/python3.12/site-packages (from intake-esgf) (1.7.4)
# Requirement already satisfied: pandas>=2.2.3 in ./.local/lib/python3.12/site-packages (from intake-esgf) (3.0.1)
# Requirement already satisfied: pystac-client>=0.8.6 in ./.local/lib/python3.12/site-packages (from intake-esgf) (0.9.0)
# Requirement already satisfied: pyyaml>=6.0.2 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from intake-esgf) (6.0.2)
# Requirement already satisfied: requests>=2.32.3 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from intake-esgf) (2.32.3)
# Requirement already satisfied: requests-cache>=1.2.1 in ./.local/lib/python3.12/site-packages (from intake-esgf) (1.3.1)
# Requirement already satisfied: tqdm>=4.67.1 in ./.local/lib/python3.12/site-packages (from intake-esgf) (4.67.3)
# Requirement already satisfied: xarray>=2024.11.0 in ./.local/lib/python3.12/site-packages (from intake-esgf) (2026.2.0)
# Requirement already satisfied: click>=8.1 in ./.local/lib/python3.12/site-packages (from dask>=2024.12.0->intake-esgf) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in ./.local/lib/python3.12/site-packages (from dask>=2024.12.0->intake-esgf) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in ./.local/lib/python3.12/site-packages (from dask>=2024.12.0->intake-esgf) (2026.2.0)
# Requirement already satisfied: packaging>=20.0 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from dask>=2024.12.0->intake-esgf) (24.1)
# Requirement already satisfied: partd>=1.4.0 in ./.local/lib/python3.12/site-packages (from dask>=2024.12.0->intake-esgf) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in ./.local/lib/python3.12/site-packages (from dask>=2024.12.0->intake-esgf) (1.1.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.0.0 in ./.local/lib/python3.12/site-packages (from pyjwt[crypto]<3.0.0,>=2.0.0->globus-sdk<4.0.0->intake-esgf) (2.11.0)
# Requirement already satisfied: cryptography!=3.4.0,>=3.3.1 in ./.local/lib/python3.12/site-packages (from globus-sdk<4.0.0->intake-esgf) (46.0.5)
# Requirement already satisfied: cftime in ./.local/lib/python3.12/site-packages (from netcdf4>=1.7.2->intake-esgf) (1.6.5)
# Requirement already satisfied: certifi in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from netcdf4>=1.7.2->intake-esgf) (2024.8.30)
# Requirement already satisfied: numpy>=1.21.2 in ./.local/lib/python3.12/site-packages (from netcdf4>=1.7.2->intake-esgf) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from pandas>=2.2.3->intake-esgf) (2.9.0)
# Requirement already satisfied: pystac>=1.10.0 in ./.local/lib/python3.12/site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.8.6->intake-esgf) (1.14.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from requests>=2.32.3->intake-esgf) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from requests>=2.32.3->intake-esgf) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from requests>=2.32.3->intake-esgf) (2.2.3)
# Requirement already satisfied: attrs>=21.2 in ./.local/lib/python3.12/site-packages (from requests-cache>=1.2.1->intake-esgf) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in ./.local/lib/python3.12/site-packages (from requests-cache>=1.2.1->intake-esgf) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from requests-cache>=1.2.1->intake-esgf) (4.3.6)
# Requirement already satisfied: url-normalize>=2.0 in ./.local/lib/python3.12/site-packages (from requests-cache>=1.2.1->intake-esgf) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in ./.local/lib/python3.12/site-packages (from cattrs>=22.2->requests-cache>=1.2.1->intake-esgf) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in ./.local/lib/python3.12/site-packages (from cryptography!=3.4.0,>=3.3.1->globus-sdk<4.0.0->intake-esgf) (2.0.0)
# Requirement already satisfied: locket in ./.local/lib/python3.12/site-packages (from partd>=1.4.0->dask>=2024.12.0->intake-esgf) (1.0.0)
# Requirement already satisfied: jsonschema~=4.18 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.8.6->intake-esgf) (4.23.0)
# Requirement already satisfied: six>=1.5 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->intake-esgf) (1.16.0)
# Requirement already satisfied: pycparser in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography!=3.4.0,>=3.3.1->globus-sdk<4.0.0->intake-esgf) (2.22)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.6->intake-esgf) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.6->intake-esgf) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.6->intake-esgf) (0.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the esgf catalogue
from intake_esgf import ESGFCatalog
cat = ESGFCatalog()

# %%
# downloading daily data for tasmin for the 
cat = (
    ESGFCatalog()
    .search(
        experiment_id="historical",
        source_id="CanESM5",
        variable_id="gpp",
        frequency="day",
        file_start="1980-01",
        file_end="2016-01",
    )
    .remove_ensembles()
)
dpd = cat.to_path_dict(minimal_keys=False)
# Out:
#    Searching indices:   0%|          |0/1 [       ?index/s]
# ---------------------------------------------------------------------------
# NoSearchResults                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 # downloading daily data for tasmin for the
#       2 cat = (
#       3     ESGFCatalog()
# ----> 4     .search(
#       5         experiment_id="historical",
#       6         source_id="CanESM5",
#       7         variable_id="gpp",
#       8         frequency="day",
#       9         file_start="1980-01",
#      10         file_end="2016-01",
#      11     )
#      12     .remove_ensembles()
#      13 )
#      14 dpd = cat.to_path_dict(minimal_keys=False)
#
# File ~/.local/lib/python3.12/site-packages/intake_esgf/catalog.py:391, in ESGFCatalog.search(self, query, quiet, file_start, file_end, **search)
#     389 with ThreadPool(len(self.indices)) as pool:
#     390     dfs = pool.imap_unordered(_search, self.indices)
# --> 391     self.df = base.combine_results(
#     392         tqdm(
#     393             dfs,
#     394             disable=quiet,
#     395             bar_format=base.bar_format,
#     396             unit="index",
#     397             unit_scale=False,
#     398             desc="Searching indices",
#     399             ascii=False,
#     400             total=len(self.indices),
#     401         ),
#     402         logger=self.logger,
#     403     )
#     404 self._set_project()
#     406 # even though we are using latest=True, because the search is distributed, we
#     407 # may have different versions from different indices.
#
# File ~/.local/lib/python3.12/site-packages/intake_esgf/base.py:257, in combine_results(dfs, logger)
#     255 if len(df) == 0:
#     256     logger.info("\x1bsearch end \x1bno results\033")
# --> 257     raise NoSearchResults()
#     258 # retrieve project information about how to combine results
#     259 project_id = df["project"].unique()
#
# NoSearchResults:
