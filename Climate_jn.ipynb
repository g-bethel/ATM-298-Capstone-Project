# %%
# import packages
import matplotlib.pyplot as plt
import pandas as pd

# %%
# install esgf
pip install intake-esgf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import ESGF catalogue & download daily data for tasmax from the CanESM5 model
from intake_esgf import ESGFCatalog

cat = (
    ESGFCatalog()
    .search(
        experiment_id="historical",
        source_id="CanESM5",
        variable_id="tasmax",
        frequency="day",
        file_start="1900-01",
        file_end="2020-01",
    )
    .remove_ensembles()
)
dpd = cat.to_path_dict(minimal_keys=False)
# Out:
# ...
# Get file information:   0%|          |0/1 [       ?index/s]

# %%
# download the collected data into an xarray
dsd = cat.to_dataset_dict()
# Out:
# ...
# Adding cell measures:   0%|          |0/1 [     ?dataset/s]

# %%
# plotting the data to see if it gives a similar result as the example plot on the esgf website
fig, ax = plt.subplots(figsize=(6, 4), tight_layout=True)
ds = dsd["tasmax"]["tasmax"].mean(dim="time") - 273.15  # to [C]
ds.plot(ax=ax, cmap="bwr", vmin=-40, vmax=40, cbar_kwargs={"label": "tasmax [C]"})
